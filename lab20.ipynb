# %%
import pandas as pd  
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = pd.read_csv("Data/marketing_customer_analysis.csv")
file.head(1)
# Out:
#    Unnamed: 0 Customer    State  Customer Lifetime Value Response Coverage  \
# 0           0  DK49336  Arizona               4809.21696       No    Basic
#
#   Education Effective To Date EmploymentStatus Gender  ...  \
# 0   College           2/18/11         Employed      M  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent               292.8  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
#
# [1 rows x 26 columns]

# %%
#Show DataFrame info.

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %%
#Describe DataFrame.

# %%
file.describe()
# Out:
#          Unnamed: 0  Customer Lifetime Value        Income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Months Since Last Claim  \
# count          10910.000000             10277.000000
# mean              93.196059                15.149071
# std               34.442532                10.080349
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
#Show a plot of the total number of responses.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(x='Response', data=file, palette='pastel')
plt.title('Distribución de Respuestas')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\464165826.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Response', data=file, palette='pastel')

# %%
#Show a plot of the response rate by the sales channel.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(x='Sales Channel', data=file, palette='pastel')
plt.title('Distribución de Respuestas')
plt.xlabel('Respuesta')
plt.ylabel('Cantidad')
plt.show()
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\1510943630.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sales Channel', data=file, palette='pastel')

# %%
#Show a plot of the response rate by the total claim amount.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Response', y='Total Claim Amount', data=file, palette='Set2')
plt.title('Response vs Total Claim Amount')
plt.xlabel('Response')
plt.ylabel('Total Claim Amount')
plt.show()
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\3303550650.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Response', y='Total Claim Amount', data=file, palette='Set2')

# %%
#Show a plot of the response rate by income.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Response', y='Income', data=file, palette='Set2')
plt.title('Response vs Income')
plt.xlabel('Response')
plt.ylabel('Income')
plt.show()
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\2954486227.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Response', y='Income', data=file, palette='Set2')

# %%
#Check the data types of the columns. Get the numeric data into dataframe called `numerical` and categorical columns in a dataframe called `categoricals`.
#(You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
file.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
numerical = file.select_dtypes(include=np.number)

# %%
numerical.sample()
# Out:
#       Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 6578        6578              36057.53702   90330                   137
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 6578                      NaN                             86
#
#       Number of Open Complaints  Number of Policies  Total Claim Amount
# 6578                        NaN                   2          192.085299

# %%
categorical = file.select_dtypes(object)

# %%
#Now we will try to check the distributions of the numerical variables visually
  #Use seaborn library to construct distribution plots for the numerical variables
  #Use Matplotlib to construct histograms

# %%
sns.distplot(numerical['Customer Lifetime Value'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Customer Lifetime Value')
plt.ylabel('Density')
plt.title('CLV Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\3513544107.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Customer Lifetime Value'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Customer Lifetime Value'].dropna(), bins=20, color='skyblue')
plt.xlabel('Customer Lifetime Value')
plt.ylabel('Density')
plt.title('CLV Distribution');

# %%
sns.distplot(numerical['Income'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Income')
plt.ylabel('Density')
plt.title('Income Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\496663616.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Income'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Income'].dropna(), bins=20, color='skyblue')
plt.xlabel('Income')
plt.ylabel('Density')
plt.title('Income Distribution');

# %%
sns.distplot(numerical['Monthly Premium Auto'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Monthly Premium Auto')
plt.ylabel('Density')
plt.title('Monthly Premium Auto Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\1711279153.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Monthly Premium Auto'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Monthly Premium Auto'].dropna(), bins=20, color='skyblue')
plt.xlabel('Monthly Premium Auto')
plt.ylabel('Density')
plt.title('Monthly Premium Auto Distribution');

# %%
sns.distplot(numerical['Months Since Last Claim'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Months Since Last Claim')
plt.ylabel('Density')
plt.title('Months Since Last Claim Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\1276569603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Months Since Last Claim'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Months Since Last Claim'].dropna(), bins=20, color='skyblue')
plt.xlabel('Months Since Last Claim')
plt.ylabel('Density')
plt.title('Months Since Last Claim Distribution');

# %%
sns.distplot(numerical['Months Since Policy Inception'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Months Since Policy Inception')
plt.ylabel('Density')
plt.title('Months Since Policy Inception Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\1826111323.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Months Since Policy Inception'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Months Since Policy Inception'].dropna(), bins=20, color='skyblue')
plt.xlabel('Months Since Policy Inception')
plt.ylabel('Density')
plt.title('Months Since Policy Inception Distribution');

# %%
sns.distplot(numerical['Number of Open Complaints'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Number of Open Complaints')
plt.ylabel('Density')
plt.title('Number of Open Complaints Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\1493208779.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Number of Open Complaints'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Number of Open Complaints'].dropna(), bins=20, color='skyblue')
plt.xlabel('Number of Open Complaints')
plt.ylabel('Density')
plt.title('Number of Open Complaints Distribution');

# %%
sns.distplot(numerical['Number of Policies'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Number of Policies')
plt.ylabel('Density')
plt.title('Number of Policies Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\930819724.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Number of Policies'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Number of Policies'].dropna(), bins=20, color='skyblue')
plt.xlabel('Number of Policies')
plt.ylabel('Density')
plt.title('Number of Policies Distribution');

# %%
sns.distplot(numerical['Total Claim Amount'].dropna(), kde=True, hist=True, color='skyblue')
plt.xlabel('Total Claim Amount')
plt.ylabel('Density')
plt.title('Total Claim Amount Distribution');
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_14072\1603389205.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical['Total Claim Amount'].dropna(), kde=True, hist=True, color='skyblue')

# %%
plt.hist(numerical['Total Claim Amount'].dropna(), bins=20, color='skyblue')
plt.xlabel('Total Claim Amount')
plt.ylabel('Density')
plt.title('Total Claim Amount Distribution');

# %%
#For the numerical variables, check the multicollinearity between the features. 
#Please note that we will use the column `total_claim_amount` later as the target variable.

# %%
correlation_matrix = numerical.corr()
total_claim_amount_correlation = correlation_matrix['Total Claim Amount']
total_claim_amount_correlation
# Out:
# Unnamed: 0                      -0.000593
# Customer Lifetime Value          0.232626
# Income                          -0.354141
# Monthly Premium Auto             0.631799
# Months Since Last Claim          0.013137
# Months Since Policy Inception    0.003095
# Number of Open Complaints       -0.011379
# Number of Policies              -0.008923
# Total Claim Amount               1.000000
# Name: Total Claim Amount, dtype: float64

# %%
#Drop one of the two features that show a high correlation between them (greater than 0.9). 
#Write code for both the correlation matrix and for seaborn heatmap. 
#If there is no pair of features that have a high correlation, then do not drop any features.

# %%
total_claim_amount_correlation = total_claim_amount_correlation.drop('Total Claim Amount')  

plt.figure(figsize=(8, 6))
sns.heatmap(total_claim_amount_correlation.to_frame(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation with Total Claim Amount')
plt.show()

# %%
#there's no high correlation
